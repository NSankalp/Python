# %% [markdown]
# <a href="https://colab.research.google.com/github/NSankalp/Python/blob/main/Python!!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Average of three numbers

# %%
a=10
b=20
c=30
avg=(a+b+c)/3
print(avg)
print(type(avg))
# Out:
# 20.0
# <class 'float'>

# %% [markdown]
# ## Multiplication of three numbers

# %%
a=10
b=20
c=30
mul=a*b*c
print(mul)
print(type(mul))
# Out:
# 6000
# <class 'int'>

# %% [markdown]
# ## Addition of two numbers (Dynamic)

# %%
a=int(input("Enter a number x:"))
b=int(input("Enter a number y:"))
add=a+b
print(add)
print(type(add))
# Out:
# Enter a number x:10
# Enter a number y:20
# 30
# <class 'int'>

# %% [markdown]
# ## Multiplication of three numbers (Dynamic)

# %%
a=int(input("Enter the number x:"))
b=int(input("Enter the number y:"))
c=int(input("Enter the number z:"))
mul=a*b*c
print(mul)
print(type(mul))
# Out:
# Enter the number x:10
# Enter the number y:20
# Enter the number z:30
# 6000
# <class 'int'>

# %% [markdown]
# ## Average of three numbers (Dynamic)

# %%
a=int(input("Enter the number x:"))
b=int(input("Enter the number y:"))
c=int(input("Enter the number z:"))
avg=(a+b+c)/3
print(avg)
print(type(avg))
# Out:
# Enter the number x:10
# Enter the number y:20
# Enter the number z:30
# 20.0
# <class 'float'>

# %% [markdown]
# ## Type Conversions:
# ### 1)int to float
# ### 2)float to int
# ### 3)int to string
# ### 4)string to int(not possible if its anything other than numbers)

# %%
a=10
print(type(a))
b=float(a)
print(b)
print(type(b))

c=23.7
print(type(c))
d=int(c)
print(d)
print(type(d))

x=20
print(type(x))
y=str(x)
print(y)
print(type(y))

s='12'
print(type(s))
t=int(s)
print(t)
print(type(t))
# Out:
# <class 'int'>
# 10.0
# <class 'float'>
# <class 'float'>
# 23
# <class 'int'>
# <class 'int'>
# 20
# <class 'str'>
# <class 'str'>
# 12
# <class 'int'>

# %% [markdown]
# ## Boolean

# %%
a=10
b=14
c=b<a
print(c)
print(type(c))
# Out:
# False
# <class 'bool'>

# %% [markdown]
# ## Conversion of boolean
# ### Boolean to int
# ### Boolean to float
# ### Boolean to string

# %%
a=10
b=20
c=b<a
d=int(c)
print(c)
print(d)
print(type(c))
print(type(d))
# Out:
# False
# 0
# <class 'bool'>
# <class 'int'>

# %%
a=10
b=20
c=b<a
d=float(c)
print(c)
print(d)
print(type(c))
print(type(d))
# Out:
# False
# 0.0
# <class 'bool'>
# <class 'float'>

# %%
a=10
b=20
c=b<a
d=str(c)
print(c)
print(d)
print(type(c))
print(type(d))
# Out:
# False
# False
# <class 'bool'>
# <class 'str'>

# %% [markdown]
# ## Complex
# ### Complex to int(not possible)
# ### Complex to float(not possible)
# ### Complex to string(Possible)
# ### Complex to bool(Possible)

# %%
a=1+10j
print(type(a))
# Out:
# <class 'complex'>

# %%
a=1+10j
print(type(a))
b=str(a)
print(type(b))
# Out:
# <class 'complex'>
# <class 'str'>

# %%
a=1+10j
print(type(a))
b=bool(a)
print(type(b))
# Out:
# <class 'complex'>
# <class 'bool'>

# %% [markdown]
# CONTROL STATEMENTS
#
# IF- ELIGIBLE FOR VOTING
#
# ELIF- GREATEST OF 3 and 5 NUMBERS, MAX MARKS IN 5 SUBS

# %%
a=20
if a>18:
    print("You are eligible for voting")
else:
    print("You are not eligible for voting")
# Out:
# You are eligible for voting

# %%
a=int(input("Enter your age"))
if a>18:
    print("You are eligible for voting")
else:
    print("You are not eligible for voting")
# Out:
# Enter your age15
# You are not eligible for voting

# %%
a=int(input("Enter num1:"))
b=int(input("Enter num2:"))
c=int(input("Enter num3:"))
if a>b and a>c:
  print("a is greatest")
elif b>a and b>c:
  print("b is greatest")
else:
  print("c is greatest")
# Out:
# Enter num1:10
# Enter num2:20
# Enter num3:15
# b is greatest

# %%
a=int(input("Enter num1:"))
b=int(input("Enter num2:"))
c=int(input("Enter num3:"))
d=int(input("Enter num4:"))
e=int(input("Enter num5:"))

if a>b and a>c and a>d and a>e:
  print("a is greatest")
elif b>a and b>c and b>d and b>e:
  print("b is greatest")
elif c>a and c>b and c>d and c>e:
  print("c is greatest")
elif d>a and d>b and d>c and d>e:
  print("d is greatest")
else:
  print("e is greatest")
# Out:
# Enter num1:2
# Enter num2:56
# Enter num3:72
# Enter num4:4
# Enter num5:99
# e is greatest

# %%
a=int(input("Enter marks of sub1:"))
b=int(input("Enter marks of sub2:"))
c=int(input("Enter marks of sub3:"))
d=int(input("Enter marks of sub4:"))
e=int(input("Enter marks of sub5:"))

if a>b and a>c and a>d and a>e:
  print("a is greatest")
elif b>a and b>c and b>d and b>e:
  print("b is greatest")
elif c>a and c>b and c>d and c>e:
  print("c is greatest")
elif d>a and d>b and d>c and d>e:
  print("d is greatest")
else:
  print("e is greatest")
# Out:
# Enter marks of sub1:77
# Enter marks of sub2:78
# Enter marks of sub3:79
# Enter marks of sub4:80
# Enter marks of sub5:81
# e is greatest

# %% [markdown]
# LOOPS

# %%
for i in range(1,5):
  print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range(1,100):
 if(i%2==0):
   print(i)
for j in range(1,100):
 if(j%2!=0):
   print(j)

# %%
for i in range(1,78,3):
 print(i)

# %% [markdown]
# MODULE 2 PROGRAMS
# 1)Triangle is equilateral, isoceles or scalene
# 2)leap year
# 3)minimum of 3 numbers
# 4)divisible by 5 and 11 or not
# 5) roots of quad eq
# 6)factorial
# 7)palindrome or not
# 8)perfect number or not
# 9)decimal to binary
# 10)fibanocci series
# 11)prime numbers
# 12)pattern(*)

# %%
a=int(input("side a"))
b=int(input("side b"))
c=int(input("side c"))

if a==b and b==c and c==a:
  print("Equlilateral triangle")
elif a==b or b==c or a==c:
  print("isoceles")
elif a!=b or b!=c or c!=a:
  print("scalene")
else:
  print("invalid")

# %%
a=int(input("year"))
if a%400==0 and a%100==0:
  print("leap year")
elif a%100!=0 and a%4==0:
  print("leap year")
else:
  print("not a leap year")

# %%
a=int(input("num1"))
b=int(input("num2"))
c=int(input("num3"))

if a<b and a<c:
  print("a is minimum")
elif b<a and b<c:
  print("b is mimumum")
else:
  print("c is minimum")

# %%
a=int(input("num"))
if a%5==0 and a%11==0:
  print("a is divisible")
else:
  print("not divisible")

# %%
import math
a=int(input("coeff of x^2"))
b=int(input("coeff of x"))
c=int(input("constant"))

d= b*b-4*a*c
sd=d**1/2
r1= ((-b+sd)/2*a)
r2= ((-b-sd)/2*a)

print(r1,r2)

# %%
a=int(input("num"))
b=1
for i in range(1,a+1):
  b=b*i
  print(b)

# %%
a=int(input("num"))
original=a
rev=0
while(a>0):
  rem=a%10
  rev=(rev*10)+rem
  a=a//10
if(original==rev):
  print("palindrome")
else:
  print("Not a palindrome")

# %%
num=int(input("Enter the number: "))  
sum=0  
for i in range(1,num):  
    if (num%i==0):  
        sum=sum+i  
if(sum==num):  
    print("It is a perfect number")  
else:  
    print("It is not a perfect number")

# %%
num=int(input("number"))
DecimalToBinary(num):

# %%
num = int(input("number "))

n1, n2 = 0, 1
c=0
while c<num:
       print(n1)
       n = n1 + n2
       n1 = n2
       n2 = n
       c+=1

# %%
num=int(input("number"))
for n in range(1,num):

    for i in range(2,n):

        if(n%i==0):

            break

    else:

        print(n)

# %%
row=int(input("number"))

for i in range(0,row):

  for j in range(0,i+1):
    print("*")
  
    
    
  print("\r")
